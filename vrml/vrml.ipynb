# %%
import pyvista as pv

# %%
pl = pv.Plotter()
pl.import_vrml("cylinder.vrml")
pl.show()
# Out:
# Widget(value='<iframe src="http://localhost:44925/index.html?ui=P_0x7f93247f0590_27&reconnect=auto" class="pyv…
